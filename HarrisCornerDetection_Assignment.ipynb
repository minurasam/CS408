# %% [markdown]
# <a href="https://colab.research.google.com/github/minurasam/CS408/blob/main/HarrisCornerDetection_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chessboard

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
filename = './images/chessboard.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F5DCC499610>

# %% [markdown]
# ## So the result of implementing Harris Corner Detection on the chessboard image gives the sharp edge corners in the image.

# %% [markdown]
# # Image 2

# %%
filename = './images/Image2.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,5,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F5DCC4EFC90>

# %% [markdown]
# # Image 3

# %%
filename = './images/Image3.JPG'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,4,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[255,0,0]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=588x548 at 0x7F5DCD612A10>

# %% [markdown]
# # Image 4

# %%
filename = './images/Image4.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,255,0]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=380x300 at 0x7F5DCC486590>

# %% [markdown]
# # Image 1

# %%
filename = './images/image1.JPG'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.08)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,255,255]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=274x246 at 0x7F5DCC486650>

# %% [markdown]
# # Image 5

# %%
filename = './images/Image5.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.02)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[255,255,0]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x680 at 0x7F5DCC43B750>

# %% [markdown]
# # After Optimizing Implementation

# %%
filename = './images/Image5.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


filter = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function on our Logo image
sharpen_img=cv2.filter2D(gray,-1,filter)


gray = np.float32(sharpen_img)
dst = cv2.cornerHarris(gray,2,3,0.02)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[255,255,0]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x680 at 0x7F5DCC43B290>

# %%
filename = './images/Image2.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


filter = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function on our Logo image
sharpen_img=cv2.filter2D(gray,-1,filter)


gray = np.float32(sharpen_img)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F5DCC4AA050>

# %%
filename = './images/Image3.JPG'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


filter = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function on our Logo image
sharpen_img=cv2.filter2D(gray,-1,filter)


gray = np.float32(sharpen_img)
dst = cv2.cornerHarris(gray,5,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[255,0,0]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=588x548 at 0x7F5DCC1BBF50>

# %%
filename = './images/Image4.jpg'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


filter = np.array([[-1, -1, -1], [-1,9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function on our Logo image
sharpen_img=cv2.filter2D(gray,-1,filter)


gray = np.float32(sharpen_img)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,255,0]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=380x300 at 0x7F5DCC1BAE90>

# %%
filename = './images/image1.JPG'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


filter = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function on our Logo image
sharpen_img=cv2.filter2D(gray,-1,filter)


gray = np.float32(sharpen_img)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,200]

cv2_imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=274x246 at 0x7F5DCC1C7990>
